# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.offline as pyo
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

#import data

insurance = pd.read_csv('insurance.csv')

# %% [markdown]
# ### Plotly graphs

# %% [markdown]
# #### Line graphs

# %%
# The charges of children grouped by region
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
insurance.groupby(['children','region']).count()['charges'].unstack().plot(ax=ax)

# %%
# The charges of children grouped by region
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
insurance.groupby(['children','sex']).count()['charges'].unstack().plot(ax=ax)

# %%
# The charges of children grouped by region
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
insurance.groupby(['children','smoker']).count()['charges'].unstack().plot(ax=ax);

# %% [markdown]
# #### Staked bar plot

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv('insurance.csv')
#data = px.data.gapminder()

#data_canada = data[data.country == 'Canada']
fig = px.bar(df, x=insurance.region, y=dinsurance.age,
              hover_data=['sex', 'smoker'], color='sex',
#              labels={'pop':'population of Canada'}, height=400)
            )
fig.show()

# %% [markdown]
# ### Histogram and boxplot

# %%
import plotly.express as px
df = px.data.tips()
fig = px.histogram(insurance, x="age", y="bmi", color="smoker",
                   marginal="box", # or violin, rug
                   hover_data=insurance.columns)
fig.show()
# Out:
# <div>
#
#
#             <div id="78ca9c06-baf6-4849-a208-d01cf972cd24" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("78ca9c06-baf6-4849-a208-d01cf972cd24")) {
#                     Plotly.newPlot(
#                         '78ca9c06-baf6-4849-a208-d01cf972cd24',
# ...

# %% [markdown]
# #### Boxplot

# %%
from plotly.graph_objs import *
import numpy as np

insurance['Age by decades'] = insurance['age'].apply(lambda x : int(x/10)* 10)
iplot([Box(y = insurance['Age by decades'])])
# Out:
# <div>
#
#
#             <div id="4cc8dc20-c0de-4b83-a498-ce09535288ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4cc8dc20-c0de-4b83-a498-ce09535288ce")) {
#                     Plotly.newPlot(
#                         '4cc8dc20-c0de-4b83-a498-ce09535288ce',
# ...
